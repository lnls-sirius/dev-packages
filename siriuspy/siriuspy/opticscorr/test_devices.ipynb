# %%
from siriuspy.devices import Tune as _TuneDevice, BunchbyBunch as _BbBDevice

# %%
td = _TuneDevice()

# %%
bbb = _BbBDevice(_BbBDevice.DEVICES.H)

# %%
bbb.wait_for_connection()
